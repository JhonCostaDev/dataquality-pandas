# %%
from dataquality import DataQuality

dataset = 'data/drivers.csv'
dataexcel = '/home/jonathan/Documents/myGitHub/dataquality-pandas/League of legend Champions 2024.csv'
food = 'foodstruct_nutritional_facts.csv'

df = DataQuality(dataset=food)

df
# Out:
# #################################
#         RESUMO DO DATASET
# #################################
#
#     Nº de linhas: 1174
#     Nº de colunas: 59
#     Total valores únicos: 10098
#     Total de Valores nulos: 18430
#
# #################################
#     DADOS NULOS por coluna:
# Food Name                                  0
# Category Name                              0
# Calcium                                   25
# Calories                                   0
# Carbs                                      0
# Cholesterol                               55
# Copper                                    80
# Fats                                       0
# Fiber                                     98
# Folate                                   103
# Iron                                      21
# Magnesium                                 61
# Monounsaturated Fat                      110
# Net carbs                                  1
# Omega-3 - DHA                            272
# ...

# %%
c,n = df.tipos_colunas()
n
# Out:
#      Blue Essence   RP  Base HP  Base mana
# 0            4800  880      650          0
# 1            3150  790      590        418
# 2            3150  790      600        200
# 3            4800  880      630        350
# 4            1350  585      685        350
# ..            ...  ...      ...        ...
# 163          4800  880      600        250
# 164          4800  880      606        480
# 165          1350  585      574        452
# 166          4800  880      630        425
# 167          3150  790      574        418
#
# [168 rows x 4 columns]
