# %%
import pandas as pd 
import numpy as np 
df = pd.read_csv('data/drivers.csv')

df
# Out:
#      driverId   driverRef number code  forename     surname         dob  \
# 0           1    hamilton     44  HAM     Lewis    Hamilton  1985-01-07
# 1           2    heidfeld     \N  HEI      Nick    Heidfeld  1977-05-10
# 2           3     rosberg      6  ROS      Nico     Rosberg  1985-06-27
# 3           4      alonso     14  ALO  Fernando      Alonso  1981-07-29
# 4           5  kovalainen     \N  KOV    Heikki  Kovalainen  1981-10-19
# ..        ...         ...    ...  ...       ...         ...         ...
# 854       856    de_vries     21  DEV      Nyck    de Vries  1995-02-06
# 855       857     piastri     81  PIA     Oscar     Piastri  2001-04-06
# 856       858    sargeant      2  SAR     Logan    Sargeant  2000-12-31
# 857       859      lawson     40  LAW      Liam      Lawson  2002-02-11
# 858       860     bearman     38  BEA    Oliver     Bearman  2005-05-08
#
#        nationality                                             url
# ...

# %%
df['nationality'].value_counts()
# Out:
# nationality
# British              166
# American             158
# Italian               99
# French                73
# German                50
# Brazilian             32
# Argentine             24
# Swiss                 23
# Belgian               23
# South African         23
# Japanese              20
# Dutch                 18
# Australian            18
# Spanish               15
# Austrian              15
# Canadian              14
# Swedish               10
# New Zealander         10
# Finnish                9
# Mexican                6
# Danish                 5
# Irish                  5
# Russian                4
# Monegasque             4
# Portuguese             4
# Rhodesian              4
# Uruguayan              4
# Colombian              3
# East German            3
# Venezuelan             3
# Indian                 2
# Thai                   2
# Polish                 1
# Hungarian              1
# Malaysian              1
# Czech                  1
# ...

# %%
# Dividir colunas categoricas e numéricas
categoricas = df.select_dtypes(exclude = np.number)

numericas = df.select_dtypes(include = np.number)

# %%
categoricas.value_counts()
# Out:
# driverRef   number  code  forename    surname    dob         nationality  url
# zunino      \N      \N    Ricardo     Zunino     1949-04-13  Argentine    http://en.wikipedia.org/wiki/Ricardo_Zunino                1
# Cannoc      \N      \N    John        Cannon     1933-06-21  Canadian     http://en.wikipedia.org/wiki/John_Cannon_(auto_racer)      1
# Changy      \N      \N    Alain       de Changy  1922-02-05  Belgian      http://en.wikipedia.org/wiki/Alain_de_Changy               1
# abate       \N      \N    Carlo       Abate      1932-07-10  Italian      http://en.wikipedia.org/wiki/Carlo_Mario_Abate             1
# abecassis   \N      \N    George      Abecassis  1913-03-21  British      http://en.wikipedia.org/wiki/George_Abecassis              1
#                                                                                                                                     ..
# ...

# %%
numericas
# Out:
#      driverId
# 0           1
# 1           2
# 2           3
# 3           4
# 4           5
# ..        ...
# 854       856
# 855       857
# 856       858
# 857       859
# 858       860
#
# [859 rows x 1 columns]

# %%
df_netflix = pd.read_csv('netflix_titles.csv')

df_netflix
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
c_categoricas = df_netflix.select_dtypes(exclude = np.number)

c_numericas = df_netflix.select_dtypes(include = np.number)

# %%
c_categoricas
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
c_numericas
# Out:
#       release_year
# 0             2020
# 1             2021
# 2             2021
# 3             2021
# 4             2021
# ...            ...
# 8802          2007
# 8803          2018
# 8804          2009
# 8805          2006
# 8806          2015
#
# [8807 rows x 1 columns]

# %%
for coluna in c_categoricas.columns:
    nulas = df_netflix[coluna].isnull().sum()
    print(f'{coluna}: {nulas}')
# Out:
# show_id: 0
# type: 0
# title: 0
# director: 2634
# cast: 825
# country: 831
# date_added: 10
# rating: 4
# duration: 3
# listed_in: 0
# description: 0

# %%
for coluna in c_numericas.columns:
    nulas = df_netflix[coluna].isnull().sum()
    print(f'{coluna}: {nulas}')
# Out:
# release_year: 0

# %%
lol = pd.read_csv('League of legend Champions 2024.csv')
lol
# Out:
#         Name               Nick Name             Classes         Release Date  \
# 0     Aatrox        The darkin blade          Juggernaut           2013-06-13
# 1       Ahri     The nine-tailed fox               Burst           2011-12-14
# 2      Akali      The rogue assassin            Assassin           2010-05-11
# 3     Akshan      The rogue sentinel  Marksman  Assassin           2021-07-22
# 4    Alistar            The minotaur            Vanguard           2009-02-21
# ..       ...                     ...                 ...                  ...
# 163     Zeri       The spark of zaun            Marksman           2022-01-20
# 164    Ziggs  The hexplosives expert           Artillery           2012-02-01
# 165   Zilean        The chronokeeper          Specialist           2009-04-18
# 166      Zoe  The aspect of twilight               Burst           2017-11-21
# 167     Zyra      Rise of the thorns             Catcher  2012-07-24 00:00:00
#
# ...
